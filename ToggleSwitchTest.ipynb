# %%
from ipywidgets import interact, interactive
from ToggleSwitch import *

# %config InlineBackend.figure_formats = {'png', 'retina'}

# %%
pi = Parameter(5.0,5.0,2,2)
init_cond = [1,1.1]
t_final = 30
x_max,y_max = 6,6

# %%
plot_solution(pi,[1,1.1],30)

# %%
plot_trajectory(pi,init_cond,t_final)

# %%
streamplot(pi,x_max,y_max)

# %%
plot_nullclines(pi,x_max,y_max)

# %%
plot_fixedpoints(pi,x_max,y_max)

# %%
w = interactive(plot_fp,A1=(1.0,5.0),A2=(1.0,5.0),B=(1.0,5.0),C=(1.0,5.0),x_max=False,y_max=False)
display(w)
# Out:
# interactive(children=(FloatSlider(value=3.0, description='A1', max=5.0, min=1.0), FloatSlider(value=3.0, descr…
