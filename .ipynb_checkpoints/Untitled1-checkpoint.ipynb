# %%
from Hysteresis import *
# %config InlineBackend.figure_formats = {'png', 'retina'}

# %%
init_cond = [.5,0]
t_final = 30
eps = .1
rhs = lambda t, y: control_rhs(t,y,EPSILON)

# %%
plot_solution(rhs,init_cond,t_final)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-6c51738338e4> in <module>
# ----> 1 plot_solution(rhs,init_cond,t_final)
#
# ~/Desktop/git/ToggleSwitch/Hysteresis.py in plot_solution(rhs, init_cond, t_final)
#      23   X = integrate.solve_ivp(rhs, [0,t_final], init_cond)
#      24   plt.plot(X.t, np.transpose(X.y))
# ---> 25   plt.xlabel('t')
#      26   plt.ylabel('c, y')
#      27   plt.legend(('c', 'y'))
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, **options)
#     475         method = METHODS[method]
#     476
# --> 477     solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     478
#     479     if t_eval is None:
#
# ...

# %%
plot_trajectory(rhs,init_cond,t_final)

# %%
streamplot(None,rhs,[-2,2],[-2,2])

# %%
plot_nullclines(None,[-2,2],[-2,2])

# %%
# Set up the figure
fig, ax = plt.subplots()
ax.set_xlabel('c')
ax.set_ylabel('y')
ax.set_aspect('equal')
# Build the plot
c_range = [-1,1]
y_range = [-1, 1]
streamplot(ax,rhs,[-2,2],[-2,2])
plot_nullclines(ax,[-2,2],[-2,2])
